# %% [markdown]
# <a href="https://colab.research.google.com/github/jons255-p/Python_Machi_Learning_Sta_Anita/blob/master/clase_4_Filtradode_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_1= pd.read_csv("SalesJan2009.csv")
df_1
# Out:
#     Transaction_date   Product Price  ...    Last_Login   Latitude   Longitude
# 0        1/2/09 6:17  Product1  1200  ...   1/2/09 6:08  51.500000   -1.116667
# 1        1/2/09 4:53  Product1  1200  ...   1/2/09 7:49  39.195000  -94.681940
# 2       1/2/09 13:08  Product1  1200  ...  1/3/09 12:32  46.188060 -123.830000
# 3       1/3/09 14:44  Product1  1200  ...  1/3/09 14:22 -36.133333  144.750000
# 4       1/4/09 12:56  Product2  3600  ...  1/4/09 12:45  33.520560  -86.802500
# ..               ...       ...   ...  ...           ...        ...         ...
# 993    1/22/09 14:25  Product1  1200  ...   3/1/09 3:37  54.583333   -5.933333
# 994     1/28/09 5:36  Product2  3600  ...   3/1/09 4:40 -20.360278   57.366111
# 995      1/1/09 4:24  Product3  7500  ...   3/1/09 7:21  42.946940  -76.429440
# 996     1/8/09 11:55  Product1  1200  ...   3/1/09 7:28  52.083333    0.433333
# 997    1/12/09 21:30  Product1  1200  ...  3/1/09 10:14  43.073060  -89.401110
#
# [998 rows x 12 columns]

# %%
df_1.head() #primeros 5
# Out:
#   Transaction_date   Product Price  ...    Last_Login   Latitude   Longitude
# 0      1/2/09 6:17  Product1  1200  ...   1/2/09 6:08  51.500000   -1.116667
# 1      1/2/09 4:53  Product1  1200  ...   1/2/09 7:49  39.195000  -94.681940
# 2     1/2/09 13:08  Product1  1200  ...  1/3/09 12:32  46.188060 -123.830000
# 3     1/3/09 14:44  Product1  1200  ...  1/3/09 14:22 -36.133333  144.750000
# 4     1/4/09 12:56  Product2  3600  ...  1/4/09 12:45  33.520560  -86.802500
#
# [5 rows x 12 columns]

# %%
df_1.sample(n=10) # muestra 10 finalas aleatorias
# Out:
#     Transaction_date   Product Price  ...     Last_Login   Latitude   Longitude
# 123      1/7/09 7:19  Product1  1200  ...   1/16/09 8:54  50.833333    4.333333
# 218    1/20/09 11:58  Product1  1200  ...  1/21/09 17:25  32.857220 -116.921390
# 926      1/5/09 3:03  Product1  1200  ...   2/26/09 4:05  51.898611   -8.495833
# 902     1/19/09 6:52  Product1  1200  ...   2/25/09 5:44  10.033333  -84.150000
# 323     1/4/09 18:34  Product1  1200  ...  1/27/09 18:37  39.115560  -77.563890
# 559     1/29/09 5:06  Product1  1200  ...   2/7/09 15:23  38.969440  -77.386390
# 52     1/10/09 14:56  Product1  1200  ...  1/10/09 19:41  41.729720  -93.605560
# 895     1/8/09 12:03  Product1  1200  ...  2/24/09 17:41  51.083333 -114.083333
# 656     1/5/09 18:55  Product1  1200  ...  2/12/09 10:25  38.942220  -77.182500
# 623    1/29/09 15:03  Product1  1200  ...  2/10/09 16:31 -36.866667  174.766667
#
# [10 rows x 12 columns]

# %%
df_1.tail() # muestra los ultimos 5
# Out:
#     Transaction_date   Product Price  ...    Last_Login   Latitude  Longitude
# 993    1/22/09 14:25  Product1  1200  ...   3/1/09 3:37  54.583333  -5.933333
# 994     1/28/09 5:36  Product2  3600  ...   3/1/09 4:40 -20.360278  57.366111
# 995      1/1/09 4:24  Product3  7500  ...   3/1/09 7:21  42.946940 -76.429440
# 996     1/8/09 11:55  Product1  1200  ...   3/1/09 7:28  52.083333   0.433333
# 997    1/12/09 21:30  Product1  1200  ...  3/1/09 10:14  43.073060 -89.401110
#
# [5 rows x 12 columns]

# %%
df_1.head(20)
# Out:
#    Transaction_date   Product Price  ...    Last_Login   Latitude   Longitude
# 0       1/2/09 6:17  Product1  1200  ...   1/2/09 6:08  51.500000   -1.116667
# 1       1/2/09 4:53  Product1  1200  ...   1/2/09 7:49  39.195000  -94.681940
# 2      1/2/09 13:08  Product1  1200  ...  1/3/09 12:32  46.188060 -123.830000
# 3      1/3/09 14:44  Product1  1200  ...  1/3/09 14:22 -36.133333  144.750000
# 4      1/4/09 12:56  Product2  3600  ...  1/4/09 12:45  33.520560  -86.802500
# 5      1/4/09 13:19  Product1  1200  ...  1/4/09 13:04  39.790000  -75.238060
# 6      1/4/09 20:11  Product1  1200  ...  1/4/09 19:45  40.693610  -89.588890
# 7      1/2/09 20:09  Product1  1200  ...  1/4/09 20:01  36.343330  -88.850280
# 8      1/4/09 13:17  Product1  1200  ...  1/4/09 22:10  32.066667   34.766667
# 9      1/4/09 14:11  Product1  1200  ...   1/5/09 1:17  48.883333    2.150000
# 10      1/5/09 2:42  Product1  1200  ...   1/5/09 4:59  40.714170  -74.006390
# ...

# %%
df_1.shape
# Out:
# (998, 12)

# %%
df_1.shape[1]
# Out:
# 12

# %%
df_1["Price"]
# Out:
# 0      1200
# 1      1200
# 2      1200
# 3      1200
# 4      3600
#        ...
# 993    1200
# 994    3600
# 995    7500
# 996    1200
# 997    1200
# Name: Price, Length: 998, dtype: object

# %%
df_1.head(2)
# Out:
#   Transaction_date   Product Price  ...   Last_Login Latitude  Longitude
# 0      1/2/09 6:17  Product1  1200  ...  1/2/09 6:08   51.500  -1.116667
# 1      1/2/09 4:53  Product1  1200  ...  1/2/09 7:49   39.195 -94.681940
#
# [2 rows x 12 columns]

# %%
df_1[df_1["Payment_Type"]=="Visa"]  #filtrado
# Out:
#     Transaction_date   Product Price  ...     Last_Login   Latitude   Longitude
# 1        1/2/09 4:53  Product1  1200  ...    1/2/09 7:49  39.195000  -94.681940
# 3       1/3/09 14:44  Product1  1200  ...   1/3/09 14:22 -36.133333  144.750000
# 4       1/4/09 12:56  Product2  3600  ...   1/4/09 12:45  33.520560  -86.802500
# 5       1/4/09 13:19  Product1  1200  ...   1/4/09 13:04  39.790000  -75.238060
# 9       1/4/09 14:11  Product1  1200  ...    1/5/09 1:17  48.883333    2.150000
# ..               ...       ...   ...  ...            ...        ...         ...
# 985    1/28/09 11:19  Product1  1200  ...  2/28/09 17:18  39.653610 -105.190560
# 990     1/5/09 13:23  Product1  1200  ...    3/1/09 2:28  48.216667   16.366667
# 993    1/22/09 14:25  Product1  1200  ...    3/1/09 3:37  54.583333   -5.933333
# 994     1/28/09 5:36  Product2  3600  ...    3/1/09 4:40 -20.360278   57.366111
# 997    1/12/09 21:30  Product1  1200  ...   3/1/09 10:14  43.073060  -89.401110
#
# ...

# %%
df_1[df_1[]]

# %%
df_1["Price"].max
# Out:
# <bound method Series.max of 0      1200
# 1      1200
# 2      1200
# 3      1200
# 4      3600
#        ...
# 993    1200
# 994    3600
# 995    7500
# 996    1200
# 997    1200
# Name: Price, Length: 998, dtype: object>

# %%
df_1[(df_1["Product"]=="Product1") & (df_1["Payment_Type"]=="Visa")]
# Out:
#     Transaction_date   Product  ... Account_Created     Last_Login
# 1        1/2/09 4:53  Product1  ...     1/2/09 4:42    1/2/09 7:49
# 3       1/3/09 14:44  Product1  ...   9/25/05 21:13   1/3/09 14:22
# 5       1/4/09 13:19  Product1  ...   9/24/08 15:19   1/4/09 13:04
# 9       1/4/09 14:11  Product1  ...     6/3/08 4:22    1/5/09 1:17
# 13      1/5/09 10:08  Product1  ...  11/11/08 15:53   1/5/09 10:05
# ..               ...       ...  ...             ...            ...
# 984    1/24/09 12:00  Product1  ...  12/30/08 15:19  2/28/09 15:17
# 985    1/28/09 11:19  Product1  ...   6/20/04 17:16  2/28/09 17:18
# 990     1/5/09 13:23  Product1  ...    1/5/09 11:28    3/1/09 2:28
# 993    1/22/09 14:25  Product1  ...  11/10/08 12:15    3/1/09 3:37
# 997    1/12/09 21:30  Product1  ...  11/17/08 22:24   3/1/09 10:14
#
# [445 rows x 10 columns]

# %%
df_1[(df_1["Product"]=="Product1") & (df_1["Payment_Type"]=="Visa")].shape[0]
# Out:
# 445

# %%
del df_1["Longitude"]
df_1
# Out:
#     Transaction_date   Product  ... Account_Created    Last_Login
# 0        1/2/09 6:17  Product1  ...     1/2/09 6:00   1/2/09 6:08
# 1        1/2/09 4:53  Product1  ...     1/2/09 4:42   1/2/09 7:49
# 2       1/2/09 13:08  Product1  ...    1/1/09 16:21  1/3/09 12:32
# 3       1/3/09 14:44  Product1  ...   9/25/05 21:13  1/3/09 14:22
# 4       1/4/09 12:56  Product2  ...  11/15/08 15:47  1/4/09 12:45
# ..               ...       ...  ...             ...           ...
# 993    1/22/09 14:25  Product1  ...  11/10/08 12:15   3/1/09 3:37
# 994     1/28/09 5:36  Product2  ...     1/9/09 8:10   3/1/09 4:40
# 995      1/1/09 4:24  Product3  ...  12/28/08 17:28   3/1/09 7:21
# 996     1/8/09 11:55  Product1  ...  11/29/06 13:31   3/1/09 7:28
# 997    1/12/09 21:30  Product1  ...  11/17/08 22:24  3/1/09 10:14
#
# [998 rows x 10 columns]

# %%
df_1[df_1["Price"]>"1500"]
# Out:
#     Transaction_date   Product  ... Account_Created     Last_Login
# 4       1/4/09 12:56  Product2  ...  11/15/08 15:47   1/4/09 12:45
# 18       1/6/09 7:45  Product2  ...     1/6/09 7:00    1/6/09 9:17
# 36      1/5/09 20:00  Product2  ...  12/10/08 19:53   1/8/09 17:58
# 39      1/6/09 22:19  Product2  ...    1/6/09 12:00   1/9/09 10:05
# 40      1/6/09 23:00  Product2  ...    1/6/09 12:00   1/9/09 10:05
# ..               ...       ...  ...             ...            ...
# 987    1/23/09 12:42  Product2  ...    3/3/08 17:38  2/28/09 22:26
# 988     1/7/09 19:48  Product2  ...   9/21/08 20:49    3/1/09 0:14
# 992    1/20/09 10:42  Product2  ...    1/20/09 9:15    3/1/09 3:29
# 994     1/28/09 5:36  Product2  ...     1/9/09 8:10    3/1/09 4:40
# 995      1/1/09 4:24  Product3  ...  12/28/08 17:28    3/1/09 7:21
#
# [155 rows x 10 columns]

# %%
df_1[df_1["Price"]>"1500"].shape[0]
# Out:
# 155

# %%
df_1.sum()

# %%
df_1.head(2)
# Out:
#   Transaction_date   Product Price  ...         Country Account_Created   Last_Login
# 0      1/2/09 6:17  Product1  1200  ...  United Kingdom     1/2/09 6:00  1/2/09 6:08
# 1      1/2/09 4:53  Product1  1200  ...   United States     1/2/09 4:42  1/2/09 7:49
#
# [2 rows x 10 columns]

# %%
df_1[(df_1["Product"]=="Product2") & (df_1["Country"]=="United States")]
# Out:
#     Transaction_date   Product  ... Account_Created     Last_Login
# 4       1/4/09 12:56  Product2  ...  11/15/08 15:47   1/4/09 12:45
# 39      1/6/09 22:19  Product2  ...    1/6/09 12:00   1/9/09 10:05
# 40      1/6/09 23:00  Product2  ...    1/6/09 12:00   1/9/09 10:05
# 43      1/7/09 15:12  Product2  ...    1/5/09 19:55   1/9/09 16:03
# 45      1/3/09 10:11  Product2  ...     1/3/09 9:27   1/10/09 9:46
# 84      1/12/09 3:03  Product2  ...    1/12/09 2:48   1/14/09 1:07
# 157    1/18/09 16:32  Product2  ...   1/18/09 16:23  1/18/09 16:54
# 158    1/18/09 17:04  Product2  ...   1/18/09 16:58  1/18/09 16:58
# 159    1/18/09 17:20  Product2  ...   1/18/09 17:16  1/18/09 17:16
# 160    1/18/09 17:39  Product2  ...   1/18/09 17:34  1/18/09 17:34
# 182    1/18/09 13:49  Product2  ...   1/11/09 12:00  1/19/09 18:07
# 204     1/10/09 8:33  Product2  ...    2/4/07 10:09  1/20/09 22:06
# 209     1/6/09 12:45  Product2  ...    1/5/09 14:06  1/21/09 11:18
# ...

# %%
df_1[(df_1["Product"]=="Product2") & (df_1["Country"]=="United States")].shape[0]
# Out:
# 55

# %%
df_1[(df_1["Product"]=="Product1") & (df_1["Country"]=="United States")]
# Out:
#     Transaction_date   Product  ... Account_Created     Last_Login
# 1        1/2/09 4:53  Product1  ...     1/2/09 4:42    1/2/09 7:49
# 2       1/2/09 13:08  Product1  ...    1/1/09 16:21   1/3/09 12:32
# 5       1/4/09 13:19  Product1  ...   9/24/08 15:19   1/4/09 13:04
# 6       1/4/09 20:11  Product1  ...     1/3/09 9:38   1/4/09 19:45
# 7       1/2/09 20:09  Product1  ...    1/2/09 17:43   1/4/09 20:01
# ..               ...       ...  ...             ...            ...
# 976    1/29/09 13:25  Product1  ...   11/3/05 18:14   2/28/09 8:27
# 979    1/23/09 10:04  Product1  ...   5/30/06 20:25   2/28/09 9:59
# 985    1/28/09 11:19  Product1  ...   6/20/04 17:16  2/28/09 17:18
# 986     1/7/09 17:48  Product1  ...   6/10/05 20:25  2/28/09 19:57
# 997    1/12/09 21:30  Product1  ...  11/17/08 22:24   3/1/09 10:14
#
# [400 rows x 10 columns]

# %%
df_1[(df_1["Product"]=="Product2") & (df_1["Country"]=="United States")].shape[0]
# Out:
# 55

# %% [markdown]
# Cuantas ventas mayor a 1300 se realizaron cn visa?

# %%
df_1[(df_1["Payment_Type"]=="Visa") & (df_1["Price"]>"1300")]
# Out:
#     Transaction_date   Product  ... Account_Created     Last_Login
# 4       1/4/09 12:56  Product2  ...  11/15/08 15:47   1/4/09 12:45
# 18       1/6/09 7:45  Product2  ...     1/6/09 7:00    1/6/09 9:17
# 36      1/5/09 20:00  Product2  ...  12/10/08 19:53   1/8/09 17:58
# 43      1/7/09 15:12  Product2  ...    1/5/09 19:55   1/9/09 16:03
# 45      1/3/09 10:11  Product2  ...     1/3/09 9:27   1/10/09 9:46
# ..               ...       ...  ...             ...            ...
# 919    1/22/09 15:59  Product2  ...    1/21/09 9:28  2/25/09 17:15
# 946    1/25/09 15:18  Product2  ...    3/2/08 15:27  2/26/09 12:58
# 949    1/20/09 10:05  Product2  ...    1/9/09 10:36  2/26/09 13:28
# 963    1/22/09 12:45  Product3  ...   1/22/09 10:25  2/27/09 10:49
# 994     1/28/09 5:36  Product2  ...     1/9/09 8:10    3/1/09 4:40
#
# [78 rows x 10 columns]

# %%
df_1[(df_1["Payment_Type"]=="Visa") & (df_1["Price"]>"1300")] [["Payment_Type","Price"]]
# Out:
#     Payment_Type Price
# 4           Visa  3600
# 18          Visa  3600
# 36          Visa  3600
# 43          Visa  3600
# 45          Visa  3600
# ..           ...   ...
# 919         Visa  3600
# 946         Visa  3600
# 949         Visa  3600
# 963         Visa  7500
# 994         Visa  3600
#
# [78 rows x 2 columns]

# %% [markdown]
# Cuantas ventas del producto 1 se realizaron en United Stated o **australia**

# %%
df_1.head(1)
# Out:
#   Transaction_date   Product Price  ...         Country Account_Created   Last_Login
# 0      1/2/09 6:17  Product1  1200  ...  United Kingdom     1/2/09 6:00  1/2/09 6:08
#
# [1 rows x 10 columns]

# %%
df_1[(df_1["Product"]=="Product1") &
     (df_1["Country"]=="United State") |
    (df_1["Country"]>"Australia")]
# Out:
#     Transaction_date   Product  ... Account_Created    Last_Login
# 0        1/2/09 6:17  Product1  ...     1/2/09 6:00   1/2/09 6:08
# 1        1/2/09 4:53  Product1  ...     1/2/09 4:42   1/2/09 7:49
# 2       1/2/09 13:08  Product1  ...    1/1/09 16:21  1/3/09 12:32
# 4       1/4/09 12:56  Product2  ...  11/15/08 15:47  1/4/09 12:45
# 5       1/4/09 13:19  Product1  ...   9/24/08 15:19  1/4/09 13:04
# ..               ...       ...  ...             ...           ...
# 993    1/22/09 14:25  Product1  ...  11/10/08 12:15   3/1/09 3:37
# 994     1/28/09 5:36  Product2  ...     1/9/09 8:10   3/1/09 4:40
# 995      1/1/09 4:24  Product3  ...  12/28/08 17:28   3/1/09 7:21
# 996     1/8/09 11:55  Product1  ...  11/29/06 13:31   3/1/09 7:28
# 997    1/12/09 21:30  Product1  ...  11/17/08 22:24  3/1/09 10:14
#
# [959 rows x 10 columns]

# %%
df_1[(df_1["Product"]=="Product1") &
     (df_1["Country"]=="United State") |
    (df_1["Country"]>"Australia")].shape[0]
# Out:
# 959

# %%
df_1[((df_1["Product"]=="Product1") &
     (df_1["Country"]=="United States")) |
    (df_1["Country"]=="Australia")] [["Product","Country"]]
# Out:
#       Product        Country
# 1    Product1  United States
# 2    Product1  United States
# 3    Product1      Australia
# 5    Product1  United States
# 6    Product1  United States
# ..        ...            ...
# 985  Product1  United States
# 986  Product1  United States
# 987  Product2      Australia
# 988  Product2      Australia
# 997  Product1  United States
#
# [438 rows x 2 columns]
